# %%
#how has the frequency of hate crime reports changed over time?
year_counts = pd.DataFrame(hate_crimes.year.value_counts().sort_index())
overall_percent_change = (100*(year_counts.loc[2023]-year_counts.loc[2019])/year_counts.loc[2019])[0]
year_counts.loc['Percentage Change (2019-2023)']=[overall_percent_change]
year_counts
# Out:
#                                     count
# year
# 2018                           102.000000
# 2019                           117.000000
# 2020                           231.000000
# 2021                           334.000000
# 2022                           381.000000
# 2023                           482.000000
# 2024                            42.000000
# Percentage Change (2019-2023)  311.965812
